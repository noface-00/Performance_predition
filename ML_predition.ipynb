# %% [markdown]
# # Proyecto de predicion de rendimiento en estudiantes de 8 a 10 años

# %% [markdown]
# ### Librerias
# - Panda
# - Sklearn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Datos de ejemplo

# %%
# Datos simulados de estudiantes
data = {
    "edad": [8, 9, 10, 8, 9, 10],
    "grado": [3, 4, 5, 3, 4, 5],
    "tipo_actividad": ["pregunta", "sopa_letras", "pregunta", "sopa_letras", "pregunta", "sopa_letras"],
    "dificultad": [1, 2, 2, 3, 2, 3],  # 1=baja,2=media,3=alta
    "tiempo_seg": [25, 120, 40, 200, 35, 180],
    "intentos": [1, 2, 1, 3, 2, 3],
    "pistas": [0, 1, 0, 0, 1, 0],
    "correcto": [1, 0, 1, 0, 1, 0],
    "nota": [9, 5, 8, 4, 7, 6],
    # Variables avanzadas
    "secuencia_actividades": [1, 2, 1, 2, 1, 2], # 1=primero fácil,2=primero difícil
    "evolucion_desempeno": [0.1, -0.2, 0.05, -0.3, 0.15, -0.1], # cambio en nota respecto al historial
    "nivel_concentracion": [0.9, 0.6, 0.85, 0.5, 0.95, 0.7], # 0-1 escala estimada
    "comparacion_historial": [0.05, -0.15, 0.1, -0.2, 0.12, -0.05], # diferencia respecto al intento anterior
    # Etiqueta final: nivel estimado del estudiante
    "nivel_comprension": ["Medio","Bajo","Alto","Bajo","Medio","Medio"]
}

df = pd.DataFrame(data)
print(df.head())
# Out:
#    edad  grado tipo_actividad  dificultad  tiempo_seg  intentos  pistas  \
# 0     8      3       pregunta           1          25         1       0
# 1     9      4    sopa_letras           2         120         2       1
# 2    10      5       pregunta           2          40         1       0
# 3     8      3    sopa_letras           3         200         3       0
# 4     9      4       pregunta           2          35         2       1
#
#    correcto  nota  secuencia_actividades  evolucion_desempeno  \
# 0         1     9                      1                 0.10
# 1         0     5                      2                -0.20
# 2         1     8                      1                 0.05
# 3         0     4                      2                -0.30
# 4         1     7                      1                 0.15
#
#    nivel_concentracion  comparacion_historial nivel_comprension
# 0                 0.90                   0.05             Medio
# ...

# %% [markdown]
# Preprocesado de datos

# %%
le = LabelEncoder()
df["tipo_actividad"] = le.fit_transform(df["tipo_actividad"])
print(df["tipo_actividad"])
X = df.drop("nivel_comprension", axis=1)
# Etiqueta
y = df["nivel_comprension"]
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    1
# Name: tipo_actividad, dtype: int64

# %% [markdown]
# Entrenamiento de modelo

# %%
# División en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Modelo
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# Evaluacion de modelo

# %%
# Evaluación
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Alto       0.00      0.00      0.00       0.0
#         Bajo       0.00      0.00      0.00       1.0
#        Medio       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# /Users/km/Documents/VSPROJ/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %% [markdown]
# Evaluacion con nuevo estudiante

# %%
nuevo_estudiante = pd.DataFrame([{
    "edad": 9,
    "grado": 4,
    "tipo_actividad": 1,
    "dificultad": 2,
    "tiempo_seg": 150,
    "intentos": 2,
    "pistas": 1,
    "correcto": 1,
    "nota": 8,
    "secuencia_actividades": 1,
    "evolucion_desempeno": 0.1,
    "nivel_concentracion": 0.8,
    "comparacion_historial": 0.05
}])


print("Nivel estimado:", model.predict(nuevo_estudiante)[0])
# Out:
# Nivel estimado: Medio
